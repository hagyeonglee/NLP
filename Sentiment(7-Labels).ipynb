# %% [markdown]
# <a href="https://colab.research.google.com/github/lhky78/NLP/blob/master/Sentiment(7-Labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
print(os.getcwd())
# !ls
# Out:
# /content
# sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! ls "/content/drive/My Drive/pytorch-bert-korean"
# Out:
#  best_model		  model_saved_pretrain	 run_pro
#  data			  optim.py		 test.py
#  datasets.py		  pretrained_model	 train_classification.py
#  dockerfile		  __pycache__		 train_mlm.py
#  font			  requirements.txt	 utils.py
#  model.py		  run
#  model_saved_finetuning  'run의 사본'

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/drive/My Drive/pytorch-bert-korean
# Out:
# /content/drive/My Drive/pytorch-bert-korean

# %%
# !pwd
# Out:
# /content/drive/My Drive/pytorch-bert-korean

# %%
# !pip install git-lfs

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 215kB 2.7MB/s
# ...
#      |████████████████████████████████| 133kB 8.8MB/s
# ...
#      |████████████████████████████████| 5.9MB 8.1MB/s
# ...
#      |████████████████████████████████| 122kB 42.8MB/s
# ...
#      |████████████████████████████████| 788kB 42.3MB/s
# ...
#      |████████████████████████████████| 51kB 9.2MB/s
# ...
#      |████████████████████████████████| 1.1MB 47.4MB/s
# ...
#      |████████████████████████████████| 133kB 51.1MB/s
# ...
#      |████████████████████████████████| 61kB 9.8MB/s
# ...
#      |████████████████████████████████| 61kB 10.9MB/s
# ...
#      |████████████████████████████████| 235kB 61.6MB/s
# ...
#      |████████████████████████████████| 399kB 49.6MB/s
# ...
#      |████████████████████████████████| 40kB 7.5MB/s
# ...
#      |████████████████████████████████| 163kB 46.5MB/s
# ...
#      |████████████████████████████████| 9.7MB 39.5MB/s
# ...
#      |████████████████████████████████| 17.4MB 113kB/s
# ...
#      |████████████████████████████████| 102kB 14.7MB/s
# ...

# %%
# !pip install -U protobuf
# Out:
# ...
#      |████████████████████████████████| 1.3MB 2.5MB/s
# ...
#   Found existing installation: protobuf 3.10.0
#     Uninstalling protobuf-3.10.0:
#       Successfully uninstalled protobuf-3.10.0
# ...

# %%
# !python train_mlm.py --pretrained_type="etri"
# Out:
# [2020-02-04 09:57:24,509] [BERT MLM] [INFO] use cuda
# [2020-02-04 09:57:24,510] [BERT MLM] [INFO] Pretrain Model : ./pretrained_model/etri/pytorch_model.bin
# [2020-02-04 09:57:44,570] [BERT MLM] [INFO] total training steps : 135, lr warmup steps : 0
# [2020-02-04 09:57:44,730] [BERT MLM] [INFO] ***** Training starts *****
# epochs:   0% 0/45 [00:00<?, ?it/s]
#
# [2020-02-04 09:57:45,636] [BERT MLM] [INFO] [0/135], trn loss : 0.015, trn acc : 0.002
# epochs:   0% 0/45 [00:00<?, ?it/s]
# steps:   0% 0/15 [00:00<?, ?it/s]
#
# [2020-02-04 09:57:45,961] [BERT MLM] [INFO] [0/135], trn loss : 0.014, trn acc : 0.002
# epochs:   0% 0/45 [00:01<?, ?it/s]
# steps:   7% 1/15 [00:00<00:09,  1.55it/s]
#
# [2020-02-04 09:57:46,278] [BERT MLM] [INFO] [0/135], trn loss : 0.015, trn acc : 0.002
# epochs:   0% 0/45 [00:01<?, ?it/s]
# steps:  13% 2/15 [00:01<00:07,  1.82it/s]
# steps:  20% 3/15 [00:01<00:05,  2.09it/s]
# steps:  27% 4/15 [00:01<00:04,  2.21it/s]
# ...

# %%
# !python train_classification.py --pretrained_type="etri"
# Out:
# [2020-02-04 09:58:01,901] [BERT Classification] [INFO] use cuda
# [2020-02-04 09:58:01,901] [BERT Classification] [INFO] use 7 labels for training
# [2020-02-04 09:58:01,901] [BERT Classification] [INFO] Pretrain Model : ./pretrained_model/etri/pytorch_model.bin
# [2020-02-04 09:58:10,883] [BERT Classification] [INFO] total training steps : 1158, lr warmup steps : 115
# [2020-02-04 09:58:11,048] [BERT Classification] [INFO] ***** Training starts *****
# epochs:   0% 0/3 [00:00<?, ?it/s]
# steps:   0% 0/386 [00:00<?, ?it/s]
# steps:   0% 1/386 [00:00<04:22,  1.47it/s]
# steps:   1% 2/386 [00:01<03:43,  1.72it/s]
# steps:   1% 3/386 [00:01<03:17,  1.93it/s]
# steps:   1% 4/386 [00:02<03:27,  1.84it/s]
# steps:   1% 5/386 [00:02<03:25,  1.86it/s]
# steps:   2% 6/386 [00:03<03:19,  1.90it/s]
# steps:   2% 7/386 [00:03<03:15,  1.94it/s]
# steps:   2% 8/386 [00:03<03:04,  2.05it/s]
# steps:   2% 9/386 [00:04<03:10,  1.98it/s]
# steps:   3% 10/386 [00:04<02:59,  2.10it/s]
# ...

# %%
# !python train_classification.py --pretrained_model_path="./model_saved_pretrain/lr0.0001,batch256,total135,warmup0.005,len90,etri/best_model.bin"
# Out:
# [2020-02-04 10:07:33,839] [BERT Classification] [INFO] use cuda
# [2020-02-04 10:07:33,839] [BERT Classification] [INFO] use 7 labels for training
# [2020-02-04 10:07:33,839] [BERT Classification] [INFO] Pretrain Model : ./model_saved_pretrain/lr0.0001,batch256,total135,warmup0.005,len90,etri/best_model.bin
# [2020-02-04 10:07:41,241] [BERT Classification] [INFO] total training steps : 1158, lr warmup steps : 115
# [2020-02-04 10:07:41,250] [BERT Classification] [INFO] ***** Training starts *****
# epochs:   0% 0/3 [00:00<?, ?it/s]
# steps:   0% 0/386 [00:00<?, ?it/s]
# steps:   0% 1/386 [00:00<04:13,  1.52it/s]
# steps:   1% 2/386 [00:00<03:35,  1.78it/s]
# steps:   1% 3/386 [00:01<03:11,  2.00it/s]
# steps:   1% 4/386 [00:01<03:24,  1.87it/s]
# steps:   1% 5/386 [00:02<03:23,  1.87it/s]
# steps:   2% 6/386 [00:02<03:18,  1.92it/s]
# steps:   2% 7/386 [00:03<03:14,  1.94it/s]
# steps:   2% 8/386 [00:03<03:03,  2.06it/s]
# steps:   2% 9/386 [00:04<03:09,  1.99it/s]
# ...

# %%
# !python train_classification.py --pretrained_model_path="./model_saved_pretrain/lr0.0001,batch256,total135,warmup0.005,len90,etri/best_model.bin"

# %%
# !python test.py --pretrained_model_path="./data/korean_single_test.csv"
# Out:
# usage: test.py [-h] [--test_data_path TEST_DATA_PATH]
# test.py: error: unrecognized arguments: --pretrained_model_path=./data/korean_single_test.csv
